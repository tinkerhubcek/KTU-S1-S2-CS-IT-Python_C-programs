# %% [markdown]
# # A ProgramTo  Make a simple **Desktop Calculator**
#
# ---

# %% [markdown]
# First we*** Define The Function*** above the Main Body Part
# We are defining each function.You can also do this by calling the** MATH Module of Python**

# %%
def add(a,b):
  sum=a+b
  print("The Sum of Two Numbers Is ",sum)
def sub(a,b):
  dif=a-b
  print("The Differnce of The Two Numbers is ",sub)
def mul(a,b):
  pro=a*b
  print("The Product of the Numbers is ",pro)
def div(a,b):
  quo=a*b
  print("The Quotient of Two Number is ",quo)

# %% [markdown]
# ### We define a *Choice variable *for Inputting the Choice and *Two Other variables* for inputting the numbers

# %%
ch=int(input("Enter Your choice \n 1.Addition \n 2.Subtraction \n 3.Multiplication \n 4.Division \n"))
a=int(input("Enter The First Number: \t"))
b=int(input("Enter the Second Number: \t"))
# Out:
# Enter Your choice
#  1.Addition
#  2.Subtraction
#  3.Multiplication
#  4.Division
# 1
# Enter The First Number: 	12
# Enter the Second Number: 	12

# %% [markdown]
# Now we Define an **IF-ELIF ladder** for each input of your Choice

# %%
if ch==1:
  add(a,b)
elif ch==2:
  sub(a,b)
elif ch==3:
  mul(a,b)
elif ch==4:
  div(a,b)
else:
  print("Invalid Input")
# Out:
# The Sum of Two Numbers Is  24
